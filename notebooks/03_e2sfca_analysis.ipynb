# %% [markdown]
# # 03 — Enhanced Two-Step Floating Catchment Area (E2SFCA) Analysis
#
# Compute spatial accessibility scores for every Pennsylvania census tract
# using the E2SFCA method with variable catchment sizes and distance decay.
#
# **Outputs per tract:**
# - Spatial accessibility score (PCPs per 1,000 pop, decay-weighted)
# - Minimum drive-time to nearest facility
# - Number of accessible facilities within catchment
# - Provider-to-population ratio

# %%
import sys
sys.path.insert(0, "..")

import geopandas as gpd
import pandas as pd

from src.config import DATA_PROCESSED, DATA_OUTPUTS
from src.spatial_analysis import (
    build_road_network,
    compute_drive_times,
    classify_urbanicity,
    e2sfca,
    sensitivity_analysis,
)
from src.visualization import choropleth_map

# %% [markdown]
# ## 3.1 Load Processed Data

# %%
tracts = gpd.read_file(DATA_PROCESSED / "pa_tracts_enriched.gpkg")
facilities_all = gpd.read_file(DATA_PROCESSED / "pa_facilities.gpkg")

# Ensure lowercase geoid column exists
if "geoid" not in tracts.columns and "GEOID" in tracts.columns:
    tracts["geoid"] = tracts["GEOID"].astype(str).str.zfill(11)

# Keep only facilities with valid point geometry for spatial analysis
facilities = facilities_all[facilities_all.geometry.notna() & ~facilities_all.geometry.is_empty].copy()
print(f"Tracts: {len(tracts)}, Facilities with geometry: {len(facilities)} / {len(facilities_all)}")
tracts.shape, facilities.shape
# Out:
# Tracts: 3446, Facilities with geometry: 1341 / 1514
# ((3446, 37), (1341, 13))

# %% [markdown]
# ## 3.2 Build Road Network Graph

# %%
network_info = build_road_network()
print("Using Euclidean distance + circuity factor approach (fast mode)")
print(f"Method: {network_info['method']}")
# Out:
# Using Euclidean distance + circuity factor approach (fast mode)
# Method: euclidean_circuity

# %% [markdown]
# ## 3.3 Compute Pairwise Drive Times

# %%
origins = tracts.copy()
origins["geometry"] = origins.geometry.centroid

tracts["urbanicity"] = classify_urbanicity(tracts).astype(str)

drive_times = compute_drive_times(
    network_info=network_info,
    origins=origins,
    destinations=facilities,
    max_minutes=30.0,
    urbanicity=tracts["urbanicity"],
)

drive_times.head(), drive_times.shape
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_98216\3685126900.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   origins["geometry"] = origins.geometry.centroid
# (     origin_id destination_id  drive_time_min
#  0  42017100102    hrsa_000821       29.690887
#  1  42017100102    hrsa_000052       29.913074
#  2  42017100102    hrsa_000379       29.444983
#  3  42017100102    hrsa_000833       29.868584
#  4  42017100102    hrsa_000811       29.291674,
#  (281142, 3))

# %% [markdown]
# ## 3.4 Classify Tract Urbanicity

# %%
# Urbanicity was already classified above in section 3.3
tracts[["geoid", "pop_density_sq_mi", "urbanicity"]].head()
# Out:
#          geoid  pop_density_sq_mi urbanicity
# 0  42017100102         390.181773      rural
# 1  42017100103        2280.221086      urban
# 2  42013010701         339.629708      rural
# 3  42013011202        1071.509953   suburban
# 4  42013011201        1706.928528   suburban

# %% [markdown]
# ## 3.5 Run E2SFCA (Baseline Parameters)

# %%
e2sfca_out = e2sfca(
    tracts=tracts,
    facilities=facilities,
    drive_times=drive_times,
)

e2sfca_out[["geoid", "accessibility_score", "nearest_facility_min", "facilities_in_catchment", "provider_pop_ratio"]].head()
# Out:
#          geoid  accessibility_score  nearest_facility_min  \
# 0  42017100102             0.000411              4.351544
# 1  42017100103             0.000026              3.233388
# 2  42013010701             0.000120              4.518516
# 3  42013011202             0.000044              9.892550
# 4  42013011201             0.000048              8.353204
#
#    facilities_in_catchment  provider_pop_ratio
# 0                      132           50.652341
# 1                       16            6.675010
# 2                        9            2.995008
# 3                        6            2.838221
# 4                        6            1.706485

# %% [markdown]
# ## 3.6 Sensitivity Analysis

# %%
sensitivity_df = sensitivity_analysis(
    tracts=tracts,
    facilities=facilities,
    drive_times=drive_times,
)

sensitivity_df.head()
# Out:
#       tract_id  threshold_offset     decay  accessibility_score
# 0  42017100102              -5.0  gaussian             0.000762
# 1  42017100103              -5.0  gaussian             0.000011
# 2  42013010701              -5.0  gaussian             0.000113
# 3  42013011202              -5.0  gaussian             0.000041
# 4  42013011201              -5.0  gaussian             0.000048

# %% [markdown]
# ## 3.7 Initial Accessibility Maps

# %%
access_map = choropleth_map(
    tracts=e2sfca_out,
    value_col="accessibility_score",
    title="Accessibility Score (E2SFCA)",
)
access_map
# Out:
# [Map output stripped for git — 37692KB HTML. Run notebook to regenerate.]

# %% [markdown]
# ## 3.8 Save Accessibility Scores

# %%
DATA_OUTPUTS.mkdir(parents=True, exist_ok=True)

e2sfca_path = DATA_OUTPUTS / "pa_accessibility_scores.gpkg"
drive_path = DATA_OUTPUTS / "pa_drive_times.csv"
sens_path = DATA_OUTPUTS / "pa_e2sfca_sensitivity.csv"
map_path = DATA_OUTPUTS / "pa_accessibility_map.html"

# De-duplicate columns (GPKG is case-insensitive)
save_df = e2sfca_out.copy()
seen = set()
keep = []
for c in save_df.columns:
    key = c.lower()
    if key not in seen:
        seen.add(key)
        keep.append(c)
save_df = save_df[keep]

save_df.to_file(e2sfca_path, driver="GPKG")
drive_times.to_csv(drive_path, index=False)
sensitivity_df.to_csv(sens_path, index=False)
access_map.save(str(map_path))

print(f"Saved: {e2sfca_path.name} ({len(save_df)} tracts), {drive_path.name} ({len(drive_times)} pairs)")
e2sfca_path, drive_path, sens_path, map_path
# Out:
# Saved: pa_accessibility_scores.gpkg (3446 tracts), pa_drive_times.csv (281142 pairs)
# (WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/outputs/pa_accessibility_scores.gpkg'),
#  WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/outputs/pa_drive_times.csv'),
#  WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/outputs/pa_e2sfca_sensitivity.csv'),
#  WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/outputs/pa_accessibility_map.html'))
