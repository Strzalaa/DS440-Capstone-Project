# %% [markdown]
# # 02 — Data Cleaning & Geocoding
#
# Clean, geocode, and merge the raw datasets into analysis-ready files.
#
# **Steps:**
# 1. Geocode all healthcare facilities to lat/lon
# 2. Validate geocoding accuracy
# 3. Cross-reference CMS and HRSA sources
# 4. Clean and join ACS demographics to census tracts
# 5. Merge SVI data
# 6. Document missing data patterns

# %%
import sys
sys.path.insert(0, "..")

import geopandas as gpd
import pandas as pd

from src.config import DATA_RAW, DATA_PROCESSED
from src.svi import mask_svi_percentile
from src.geocoding import (
    geocode_facilities,
    validate_coordinates,
    cross_reference_sources,
)

# %% [markdown]
# ## 2.1 Load Raw Data

# %%
cms_path = DATA_RAW / "cms" / "cms_facilities_standardized.csv"
hrsa_path = DATA_RAW / "hrsa" / "hrsa_facilities_standardized.csv"
urgent_path = DATA_RAW / "urgent_care" / "urgent_care_facilities_standardized.csv"
pos_path = DATA_RAW / "cms_pos" / "cms_pos_standardized.csv"
npi_path = DATA_RAW / "npi" / "npi_facilities_standardized.csv"
acs_path = DATA_RAW / "acs" / "acs_2022_tract_42.csv"
svi_path = DATA_RAW / "svi" / "SVI_2022_Pennsylvania.csv"
tracts_path = DATA_RAW / "tiger" / "tl_2024_42_tract.gpkg"

cms_df = pd.read_csv(cms_path) if cms_path.exists() else pd.DataFrame()
hrsa_df = pd.read_csv(hrsa_path) if hrsa_path.exists() else pd.DataFrame()
urgent_df = pd.read_csv(urgent_path) if urgent_path.exists() else pd.DataFrame()
pos_df = pd.read_csv(pos_path) if pos_path.exists() else pd.DataFrame()
npi_df = pd.read_csv(npi_path) if npi_path.exists() else pd.DataFrame()
acs_df = pd.read_csv(acs_path)
svi_df = pd.read_csv(svi_path)
tracts_gdf = gpd.read_file(tracts_path)

{
    "cms (hospitals)": cms_df.shape,
    "hrsa (health centers)": hrsa_df.shape,
    "urgent_care": urgent_df.shape,
    "cms_pos": pos_df.shape,
    "npi": npi_df.shape,
    "acs": acs_df.shape,
    "svi": svi_df.shape,
    "tracts": tracts_gdf.shape,
}
# Out:
# {'cms (hospitals)': (252, 10),
#  'hrsa (health centers)': (378, 10),
#  'urgent_care': (310, 10),
#  'cms_pos': (0, 0),
#  'npi': (7128, 10),
#  'acs': (3446, 13),
#  'svi': (3445, 161),
#  'tracts': (3446, 14)}

# %% [markdown]
# ## 2.2 Geocode Healthcare Facilities

# %%
def _maybe_geocode(df, batch_only=False):
    if df is None or df.empty:
        return gpd.GeoDataFrame(
            df if df is not None else pd.DataFrame(),
            geometry=[],
            crs="EPSG:4326",
        )
    return geocode_facilities(df, batch_only=batch_only)

# HIFLD/HRSA/ASC/RHC layers are already pre-geocoded; calls are effectively no-ops.
cms_geo = _maybe_geocode(cms_df)
hrsa_geo = _maybe_geocode(hrsa_df)
urgent_geo = _maybe_geocode(urgent_df)
pos_geo = _maybe_geocode(pos_df)

# NPI gap-fill has ~7k address-only records. Most are duplicates of the pre-geocoded
# layers and will be dropped in the merge. Use batch_only=True so we skip the slow
# per-address Census/Nominatim fallbacks (~hours) and rely on the bulk batch geocoder
# plus spatial de-duplication to keep only genuinely new facilities.
npi_geo = _maybe_geocode(npi_df, batch_only=True)

{
    "cms_geo": cms_geo.shape,
    "hrsa_geo": hrsa_geo.shape,
    "urgent_geo": urgent_geo.shape,
    "pos_geo": pos_geo.shape,
    "npi_geo": npi_geo.shape,
}
# Out:
#   Batch geocoding 7128 facilities via Census API...
#   Batch geocoded 6434 / 7128 facilities
#   batch_only=True: skipping per-address fallbacks (694 remaining ungeocoded)
# {'cms_geo': (252, 12),
#  'hrsa_geo': (378, 12),
#  'urgent_geo': (310, 12),
#  'pos_geo': (0, 1),
#  'npi_geo': (7128, 12)}

# %% [markdown]
# ## 2.3 Validate Coordinates

# %%
state_boundary = tracts_gdf.dissolve().to_crs("EPSG:4326")

def _maybe_validate(gdf):
    if gdf is None or gdf.empty:
        return pd.DataFrame()
    return validate_coordinates(gdf, state_boundary)

cms_validation = _maybe_validate(cms_geo)
hrsa_validation = _maybe_validate(hrsa_geo)
urgent_validation = _maybe_validate(urgent_geo)
pos_validation = _maybe_validate(pos_geo)
npi_validation = _maybe_validate(npi_geo)

{
    "cms_valid": int(cms_validation.get("is_valid", pd.Series(dtype=bool)).sum()),
    "hrsa_valid": int(hrsa_validation.get("is_valid", pd.Series(dtype=bool)).sum()),
    "urgent_valid": int(urgent_validation.get("is_valid", pd.Series(dtype=bool)).sum()),
    "pos_valid": int(pos_validation.get("is_valid", pd.Series(dtype=bool)).sum()),
    "npi_valid": int(npi_validation.get("is_valid", pd.Series(dtype=bool)).sum()),
}
# Out:
# {'cms_valid': 252,
#  'hrsa_valid': 378,
#  'urgent_valid': 310,
#  'pos_valid': 0,
#  'npi_valid': 6432}

# %% [markdown]
# ## 2.4 Cross-Reference and De-duplicate Facility Sources

# %%
facilities_gdf = cross_reference_sources(
    cms_geo,
    hrsa_geo,
    urgent_geo,
    pos_geo,
    npi_geo,
    priority=[
        "hifld_hospitals",
        "critical_access_hospital",
        "cms",
        "hrsa_hc",
        "hrsa",
        "hifld_urgent_care",
        "rural_health_clinic",
        "urgent_care",
        "cms_pos",
        "npi",
    ],
)

# Drop records with no geometry (ungeocoded NPI gap-fill leftovers) — they cannot
# be used for spatial accessibility analysis.
before = len(facilities_gdf)
facilities_gdf = facilities_gdf[
    facilities_gdf.geometry.notna() & ~facilities_gdf.geometry.is_empty
].reset_index(drop=True)
print(f"Dropped {before - len(facilities_gdf)} ungeocoded records (no geometry)")

print(f"Merged facility count: {len(facilities_gdf)}")
if "source_provenance" in facilities_gdf.columns:
    print("Source provenance distribution:")
    print(facilities_gdf["source_provenance"].value_counts().head(20))
facilities_gdf.head()
# Out:
# Dropped 481 ungeocoded records (no geometry)
# Merged facility count: 4638
# Source provenance distribution:
# source_provenance
# npi                                                      3802
# hrsa_hc+npi                                               244
# hifld_urgent_care+npi                                     202
# hifld_hospitals+npi                                       146
# hrsa_hc                                                    75
# hifld_urgent_care                                          65
# hifld_hospitals+hifld_hospitals+npi                        16
# hifld_hospitals+npi+npi                                    14
# hrsa_hc+hrsa_hc+npi                                        13
# hifld_hospitals                                            12
# hifld_hospitals+hifld_urgent_care+npi                      11
# hifld_hospitals+hrsa_hc+npi                                 7
# hifld_urgent_care+hrsa_hc+npi                               7
# ...

# %% [markdown]
# ## 2.5 Merge Demographics and SVI to Tract Geometries

# %%
tracts = tracts_gdf.copy()
tracts["geoid"] = tracts["GEOID"].astype(str).str.zfill(11)
acs_df["geoid"] = acs_df["geoid"].astype(str).str.zfill(11)
tracts = tracts.merge(acs_df, on="geoid", how="left")

svi_df["FIPS"] = svi_df["FIPS"].astype(str).str.zfill(11)
svi_cols = [c for c in ["FIPS", "RPL_THEMES", "RPL_THEME1", "RPL_THEME2", "RPL_THEME3", "RPL_THEME4"] if c in svi_df.columns]
tracts = tracts.merge(svi_df[svi_cols], left_on="geoid", right_on="FIPS", how="left")

tracts["pct_no_vehicle"] = (tracts["households_no_vehicle"] / tracts["households"]).replace([pd.NA, pd.NaT], pd.NA) * 100
tracts["pct_no_vehicle"] = pd.to_numeric(tracts["pct_no_vehicle"], errors="coerce")
tracts.loc[~tracts["pct_no_vehicle"].between(0, 100, inclusive="both"), "pct_no_vehicle"] = pd.NA

tracts["median_household_income"] = pd.to_numeric(tracts["median_household_income"], errors="coerce")
tracts.loc[tracts["median_household_income"] < 0, "median_household_income"] = pd.NA

if "pct_uninsured" not in tracts.columns:
    tracts["pct_uninsured"] = pd.NA
else:
    tracts["pct_uninsured"] = pd.to_numeric(tracts["pct_uninsured"], errors="coerce")
    tracts.loc[~tracts["pct_uninsured"].between(0, 100, inclusive="both"), "pct_uninsured"] = pd.NA
print(f"pct_uninsured: {tracts['pct_uninsured'].notna().sum()} / {len(tracts)} tracts have data")
tracts["svi_overall"] = tracts.get("RPL_THEMES")
_svi_cols = [
    c for c in ["RPL_THEMES", "RPL_THEME1", "RPL_THEME2", "RPL_THEME3", "RPL_THEME4", "svi_overall"]
    if c in tracts.columns
]
for _col in _svi_cols:
    tracts[_col] = mask_svi_percentile(tracts[_col])

tracts_proj = tracts.to_crs(3857)
tracts["area_sq_mi"] = tracts_proj.geometry.area / 2_589_988.110336
tracts["pop_density_sq_mi"] = tracts["total_population"] / tracts["area_sq_mi"]

tracts[["geoid", "total_population", "median_household_income", "pct_uninsured", "pct_no_vehicle", "svi_overall"]].head()
# Out:
# pct_uninsured: 3406 / 3446 tracts have data
#          geoid  total_population  median_household_income  pct_uninsured  \
# 0  42017100102              2606                  77946.0            7.9
# 1  42017100103              2397                  64417.0            2.8
# 2  42013010701              3005                  78700.0            1.7
# 3  42013011202              2114                  54792.0            3.2
# 4  42013011201              3516                  68380.0            0.6
#
#    pct_no_vehicle  svi_overall
# 0        8.792846       0.6442
# 1       12.687313       0.7391
# 2        8.855292       0.3570
# 3        9.172483       0.2727
# 4        5.623472       0.1497

# %% [markdown]
# ## 2.6 Missing Data Report

# %%
missing_report = pd.DataFrame(
    {
        "column": tracts.columns,
        "missing_n": [tracts[c].isna().sum() for c in tracts.columns],
    }
)
missing_report["missing_pct"] = (missing_report["missing_n"] / len(tracts)) * 100
missing_report.sort_values("missing_pct", ascending=False).head(20)
# Out:
#                      column  missing_n  missing_pct
# 17  median_household_income         63     1.828207
# 28               RPL_THEMES         46     1.334881
# 29               RPL_THEME1         46     1.334881
# 34              svi_overall         46     1.334881
# 32               RPL_THEME4         45     1.305862
# 33           pct_no_vehicle         45     1.305862
# 30               RPL_THEME2         45     1.305862
# 26            pct_uninsured         40     1.160766
# 31               RPL_THEME3         32     0.928613
# 27                     FIPS          1     0.029019
# 0                   STATEFP          0     0.000000
# 2                   TRACTCE          0     0.000000
# 1                  COUNTYFP          0     0.000000
# 4                   GEOIDFQ          0     0.000000
# 3                     GEOID          0     0.000000
# 7                     MTFCC          0     0.000000
# 5                    NAME_x          0     0.000000
# ...

# %% [markdown]
# ## 2.7 Save Processed Datasets

# %%
DATA_PROCESSED.mkdir(parents=True, exist_ok=True)

tracts_out = DATA_PROCESSED / "pa_tracts_enriched.gpkg"
facilities_out = DATA_PROCESSED / "pa_facilities.gpkg"
missing_out = DATA_PROCESSED / "missing_data_report.csv"

# GPKG treats field names case-insensitively; keep only one version per lower-case name.
tracts_to_save = tracts.copy()
seen = set()
keep_cols = []
for col in tracts_to_save.columns:
    key = col.lower()
    if key in seen:
        continue
    seen.add(key)
    keep_cols.append(col)
tracts_to_save = tracts_to_save[keep_cols]

tracts_to_save.to_file(tracts_out, driver="GPKG")
facilities_gdf.to_file(facilities_out, driver="GPKG")
missing_report.to_csv(missing_out, index=False)

tracts_out, facilities_out, missing_out
# Out:
# (WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/processed/pa_tracts_enriched.gpkg'),
#  WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/processed/pa_facilities.gpkg'),
#  WindowsPath('C:/Users/saksh/Desktop/DS440-Capstone-Project/data/processed/missing_data_report.csv'))
