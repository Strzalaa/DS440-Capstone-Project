# %% [markdown]
# # 05 — Clustering: Community Typology by Healthcare Access Profile
#
# Identify groups of census tracts with similar healthcare access challenges
# using unsupervised machine learning.
#
# **Methods:**
# 1. Feature engineering and standardisation
# 2. K-means clustering with optimal-k selection
# 3. Hierarchical clustering (validation)
# 4. LISA spatial clustering
# 5. Cluster characterisation and intervention mapping

# %%
import sys
sys.path.insert(0, "..")

import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

from src.config import DATA_OUTPUTS
from src.clustering import (
    prepare_features,
    kmeans_optimal_k,
    hierarchical_clustering,
    spatial_clustering,
    characterize_clusters,
)
from src.visualization import plot_elbow, cluster_map

# %% [markdown]
# ## 5.1 Load Accessibility and Demographic Data

# %%
cluster_gdf = gpd.read_file(DATA_OUTPUTS / "pa_accessibility_scores.gpkg")
if "geoid" not in cluster_gdf.columns and "GEOID" in cluster_gdf.columns:
    cluster_gdf["geoid"] = cluster_gdf["GEOID"].astype(str).str.zfill(11)
cluster_gdf.shape, cluster_gdf.head()
# Out:
# ((3446, 42),
#    STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ   NAME_x  \
#  0      42      017  100102  42017100102  1400000US42017100102  1001.02
#  1      42      017  100103  42017100103  1400000US42017100103  1001.03
#  2      42      013  010701  42013010701  1400000US42013010701   107.01
#  3      42      013  011202  42013011202  1400000US42013011202   112.02
#  4      42      013  011201  42013011201  1400000US42013011201   112.01
#
#                 NAMELSAD  MTFCC FUNCSTAT     ALAND  ...  svi_overall  \
#  0  Census Tract 1001.02  G5020        S   7695740  ...       0.6442
#  1  Census Tract 1001.03  G5020        S   1578123  ...       0.7391
#  2   Census Tract 107.01  G5020        S  13212402  ...       0.3570
#  3   Census Tract 112.02  G5020        S   2957912  ...       0.2727
#  4   Census Tract 112.01  G5020        S   3087322  ...       0.1497
#
#    area_sq_mi pop_density_sq_mi urbanicity  accessibility_score  \
#  0   6.678938        390.181773      rural             0.000411
#  1   1.051214       2280.221086      urban             0.000026
#  2   8.847871        339.629708      rural             0.000120
#  3   1.972917       1071.509953   suburban             0.000044
#  4   2.059840       1706.928528   suburban             0.000048
#
#     nearest_facility_min  facilities_in_catchment  provider_pop_ratio  \
#  0              4.351544                      132           50.652341
#  1              3.233388                       16            6.675010
#  2              4.518516                        9            2.995008
#  3              9.892550                        6            2.838221
#  4              8.353204                        6            1.706485
#
#                                              geometry        geoid
#  0  MULTIPOLYGON (((-74.98425 40.0559, -74.98354 4...  42017100102
#  1  MULTIPOLYGON (((-74.98519 40.05711, -74.98515 ...  42017100103
#  2  MULTIPOLYGON (((-78.42491 40.54761, -78.42469 ...  42013010701
#  3  MULTIPOLYGON (((-78.41684 40.42682, -78.41678 ...  42013011202
#  4  MULTIPOLYGON (((-78.41251 40.43304, -78.41208 ...  42013011201
#
#  [5 rows x 42 columns])

# %% [markdown]
# ## 5.2 Feature Engineering

# %%
X, feature_names = prepare_features(cluster_gdf)
X.shape, feature_names
# Out:
# ((3446, 7),
#  ['accessibility_score',
#   'nearest_facility_min',
#   'provider_pop_ratio',
#   'median_household_income',
#   'pct_uninsured',
#   'pct_no_vehicle',
#   'svi_overall'])

# %% [markdown]
# ## 5.3 K-Means — Optimal k Selection

# %%
kmeans_result = kmeans_optimal_k(X)
cluster_gdf["cluster"] = kmeans_result["labels"].astype(int)

k_vals = range(2, 2 + len(kmeans_result["inertias"]))
elbow_fig = plot_elbow(kmeans_result["inertias"], kmeans_result["silhouette_scores"], k_vals)
elbow_fig

# %% [markdown]
# ## 5.4 Hierarchical Clustering (Validation)

# %%
hier_result = hierarchical_clustering(X, n_clusters=kmeans_result["optimal_k"])
cluster_gdf["cluster_hier"] = hier_result["labels"].astype(int)
cluster_gdf[["cluster", "cluster_hier"]].head()
# Out:
#    cluster  cluster_hier
# 0        0             1
# 1        0             1
# 2        0             1
# 3        0             1
# 4        0             1

# %% [markdown]
# ## 5.5 LISA Spatial Clustering

# %%
cluster_gdf = spatial_clustering(cluster_gdf, variable="accessibility_score")
cluster_gdf[["spatial_cluster"]].value_counts().head()
# Out:
# C:\Users\saksh\Desktop\DS440-Capstone-Project\notebooks\..\src\statistics.py:223: FutureWarning:
#
# `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
# spatial_cluster
# Not Significant           2140
# Low Access Cluster         820
# High Access Cluster        391
# Spatial Outlier (Low)       88
# Spatial Outlier (High)       7
# Name: count, dtype: int64

# %% [markdown]
# ## 5.6 Cluster Characterisation

# %%
cluster_profiles = characterize_clusters(cluster_gdf, label_col="cluster")
cluster_profiles
# Out:
#    cluster  accessibility_score_mean  accessibility_score_median  \
# 0        0                  0.000085                    0.000068
# 1        1                  0.001536                    0.000416
#
#    nearest_facility_min_mean  nearest_facility_min_median  \
# 0                   6.088179                     3.115224
# 1                   3.294274                     1.973981
#
#    provider_pop_ratio_mean  provider_pop_ratio_median  \
# 0                12.116437                   4.027801
# 1               783.372298                   0.000000
#
#    median_household_income_mean  median_household_income_median  \
# 0                 -3.452280e+06                         70129.5
# 1                 -6.521733e+08                    -666666666.0
#
#    pct_uninsured_mean  pct_uninsured_median  pct_no_vehicle_mean  \
# 0            5.533333                   4.3             10.98498
# 1            5.442857                   2.8             50.00000
#
#    pct_no_vehicle_median  svi_overall_mean  svi_overall_median  n_tracts  \
# 0                6.40884          0.417349              0.3794      3400
# 1               50.00000       -977.280604           -999.0000        46
#
#    total_population
# 0          12963976
# 1             25232

# %% [markdown]
# ## 5.7 Cluster Maps

# %%
cluster_folium_map = cluster_map(cluster_gdf, cluster_col="cluster")

cluster_out = DATA_OUTPUTS / "pa_accessibility_clusters.gpkg"
profile_out = DATA_OUTPUTS / "pa_cluster_profiles.csv"
map_out = DATA_OUTPUTS / "pa_cluster_map.html"

# De-duplicate columns for GPKG case-insensitivity
save_df = cluster_gdf.copy()
seen = set()
keep = []
for c in save_df.columns:
    key = c.lower()
    if key not in seen:
        seen.add(key)
        keep.append(c)
save_df = save_df[keep]

save_df.to_file(cluster_out, driver="GPKG")
cluster_profiles.to_csv(profile_out, index=False)
cluster_folium_map.save(str(map_out))

print(f"Saved: {cluster_out.name}, {profile_out.name}, {map_out.name}")
cluster_folium_map
# Out:
# Saved: pa_accessibility_clusters.gpkg, pa_cluster_profiles.csv, pa_cluster_map.html
# [Large map output removed to keep file size under GitHub limit]
